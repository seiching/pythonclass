# %%
from sklearn.linear_model import LinearRegression
import sqlite3
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import date,timedelta
import matplotlib
plt.close('all')
matplotlib.style.use('ggplot')
conn = sqlite3.connect('hackson.db')
#a=pd.read_sql('SELECT substr(列帳日期,1,3)+1911 as yyyy ,substr(列帳日期,4,2) as mm,substr(列帳日期,6,2)as dd FROM "12加油站每日銷售發票張數V3UTF8";',conn)
#sqlstr="SELECT avg(主油品) as sale ,nextdifference FROM 加油站每日銷售發票張數 a , 加油站服務資訊utf821 b where a.站代碼=b.站代號 and  站代號='D414K' \
 #   and weekno>5 group by  nextdifference  order by nextdifference ;"
sqlstr="SELECT 站代號, 縣市, avgweekdaysale, slope, interception, r2, 平均發票油量,站名 \
         FROM 加油站服務資訊utf821 a ,平均發票發油量 b  where a.縣市=b.city  and r2>0 order by r2 desc;"
pdoil=pd.read_sql(sqlstr,conn)
result=list()
pricechange=float(input("油價漲跌幅"))
daylen=float(input("離星期日幾天"))
if(daylen>2):
    weeekdaylen=daylen-2
    weekendaylen=2
else:
    weekdaylen=0
    weekendaylen=daylen
    

for i in range(0,len(pdoil)):
   station= pdoil.iloc[i,0]
   city=pdoil.iloc[i,1]
   avgweekdaysale=pdoil.iloc[i,2]
   slope=pdoil.iloc[i,3]
   interception=pdoil.iloc[i,4]
   stationname=pdoil.iloc[i,7]
   estimaterecepit=(pricechange*slope+interception)*weekendaylen+avgweekdaysale* weekendaylen
    
  # print('receipt',estimaterecepit,'oil=',pdoil.iloc[i,6])
  # print()
   estimateoilsale=estimaterecepit*float(pdoil.iloc[i,6])
   #print(station," estimate receipt=", estimaterecepit,' estimateoilsale=',estimateoilsale)
   
   r2=pdoil.iloc[i,5]
   inventory=100-estimateoilsale
   item=[station,city,stationname,estimaterecepit, estimateoilsale,inventory]

  # item=[stationname, estimateoilsale,inventory]
   result.append(item)
  

resultpd=pd.DataFrame(result)
resultpd.columns=['油站代號','縣市','站名','預估發票量','預估銷售量','預估存量']
#resultpd.columns=['站名','預估銷售量','預估存量']
#a.columns=['a','b','c','d','e']
#totalsale=a['e'].sum()
totalsale=a['預估銷售量'].sum()

resultpds=resultpd.sort_values(by=['預估銷售量'],ascending=0)
print('銷售量= ',totalsale)

resultpds
# Out:
# 油價漲跌幅1
# 離星期日幾天3
# 銷售量=  41782.169635300284
#       油站代號   縣市          站名         預估發票量       預估銷售量        預估存量
# 468  D2149  台北市       民權西路站  22819.383723  343.280714 -243.280714
# 407  D2142  台北市         北投站  16845.016493  253.406024 -153.406024
# 325  D215H  新北市      板橋民族路站  23419.446654  237.944421 -137.944421
# 253  D215T  台北市        莒光路站  15145.656392  227.841900 -127.841900
# 148  D514Z  高雄市         鳳松站  22235.196969  220.458328 -120.458328
# 394  D4262  新竹市        北大路站  16590.403060  205.881967 -105.881967
# 283  D2176  台北市       光復北路站  13576.023353  204.229310 -104.229310
# 160  D214R  台北市         內湖站  13417.486806  201.844384 -101.844384
# 189  D214Y  台北市       建國北路站  13248.163258  199.297185  -99.297185
# 508  D216F  新北市      永和永利路站  19528.905468  198.416051  -98.416051
# 353  D215K  新北市         蘆洲站  19525.762671  198.384119  -98.384119
# 328  D215J  台北市         南港站  13064.351392  196.532033  -96.532033
# 211  D215L  台北市       環河南路站  12480.433871  187.747939  -87.747939
# 454  D2178  台北市       林森北路站  11854.013805  178.324462  -78.324462
# 350  D2049  基隆市       成功一路站  10809.393025  175.779752  -75.779752
# 182  D4247  新竹縣         府前站  12098.822666  170.086023  -70.086023
# 330  D6165  宜蘭縣         員山站   9945.022252  167.209369  -67.209369
# 399  D214F  新北市         菜寮站  16389.309882  166.517378  -66.517378
# 400  D214M  台北市       忠孝東路站  11004.747492  165.548624  -65.548624
# 486  D2162  台北市        桂林路站  10981.997969  165.206394  -65.206394
# 488  D2144  台北市        基隆路站  10893.951245  163.881874  -63.881874
# 273  D2171  新北市         重陽路  15957.588176  162.131033  -62.131033
# 375  D2061  基隆市        東明路站   9936.306984  161.581837  -61.581837
# 346  D2150  台北市         木柵站  10740.567797  161.574468  -61.574468
# 188  D2169  台北市        富陽街站  10704.769382  161.035939  -61.035939
# 171  D215V  新北市     泰新加油加氣站  15843.973170  160.976691  -60.976691
# 163  D515E  高雄市         瑞豐站  16220.189517  160.820517  -60.820517
# 471  D2157  台北市       復興北路站  10390.387040  156.306565  -56.306565
# 258  D426G  苗栗縣         中苗站  12778.882134  155.878486  -55.878486
# 45   D5165  高雄市         高鳳站  15667.512066  155.340811  -55.340811
# ..     ...  ...         ...           ...         ...         ...
# 600  D616G  宜蘭縣         北關站    813.728076   13.681514   86.318486
# 531  D615A  花蓮縣         國光站   1043.479270   13.571208   86.428792
# 230  D427E  苗栗縣         大坪站   1100.336083   13.422044   86.577956
# 571  D616H  宜蘭縣         南山站    797.413497   13.407211   86.592789
# 540  D515Z  屏東縣         滿州站   1514.903371   12.756424   87.243576
# 555  D435G  嘉義縣         大埔站    858.561911   12.688850   87.311150
# 597  D509C  台南市         光州站   1213.618074   12.514038   87.485962
# 526  D6176  台東縣         長濱站   1133.534962   12.273969   87.726031
# 578  D616B  宜蘭縣        南方澳站    715.095576   12.023169   87.976831
# 65   D237Y  桃園市         廣豐站   1004.880397   12.001870   87.998130
# 391  D4259  新竹縣         峨眉站    849.053696   11.936051   88.063949
# 561  D426A  苗栗縣         獅潭站    959.545302   11.704660   88.295340
# 548  D436H  澎湖縣         七美站    621.266921   11.530561   88.469439
# 610  D43X5  嘉義縣       阿里山新站    718.572854   10.619925   89.380075
# 553  D6154  花蓮縣        赤科山站    767.291511    9.979185   90.020815
# 598  D516Y  高雄市        蚵仔寮站    994.712840    9.862415   90.137585
# 583  D517E  高雄市         南寮站    975.571037    9.672627   90.327373
# 581  D434M  雲林縣        三條崙站    695.083478    9.463482   90.536518
# 586  D6148  花蓮縣         豐濱站    642.734815    8.359234   91.640766
# 568  D414H  南投縣          溪頭    647.428677    7.627029   92.372971
# 605  D436L  澎湖縣         外垵站    379.523130    7.043856   92.956144
# 604  D505Q  台南市         左鎮站    634.068865    6.538104   93.461896
# 405  D516A  高雄市        漁港路站    633.998477    6.285991   93.714009
# 577  D436K  澎湖縣         望安站    319.388192    5.927766   94.072234
# 519  D617G  台東縣         泰源站    512.725836    5.551819   94.448181
# 582  D616A  宜蘭縣         大里站    300.949022    5.059968   94.940032
# 574  D6152  花蓮縣         關原站    308.300756    4.009676   95.990324
# 559  D617B  台東縣         東河站    349.749103    3.787100   96.212900
# 550  D517R  高雄市  前鎮漁港路加油加氣站    266.806299    2.645341   97.354659
# 443  D5162  高雄市      36號碼頭站    245.980847    2.438860   97.561140
#
# [611 rows x 6 columns]

# %%
# Out:
# 油價1
# 1
